# %% [markdown]
# ## Bibliotecas necessárias

# %%
# Importação de Bibliotecas Necessárias
import numpy as np
import pandas as pd
import librosa
import librosa.display
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, Conv1D,MaxPooling1D,LeakyReLU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD,Adam
import soundata
import tensorflow as tf
import os
import librosa
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Extração de features e download dos sons

# %%
dfclass = pd.read_csv(r'UrbanSound8K.csv')
dfclass.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
FOLDS_PATH = "../UrbanSound8K/audio/"

# %%
def load_fold_data(features_file, labels_file, label_encoder):
    features = pd.read_csv(features_file).values
    labels = pd.read_csv(labels_file)['0']
    encoded_labels = label_encoder.transform(labels)
    return features, encoded_labels

# %%
def create_label_mapping(folds_path, n_folds):
    all_labels = set()
    for fold_number in range(1, n_folds + 1):
        labels_file = f'csv/labelsfold{fold_number}.csv'
        df_labels = pd.read_csv(labels_file)
        all_labels.update(df_labels['0'].unique())
    
    label_encoder = LabelEncoder()
    label_encoder.fit(list(all_labels))
    return label_encoder

# %%
def load_data(FOLDS_PATH):
    features = []
    labels = []
    
    folds = [fold for fold in os.listdir(FOLDS_PATH) if "fold" in fold]
    for fold in folds:
        audio_files = librosa.util.find_files(FOLDS_PATH+"/"+fold)
        features = []
        labels = []
        for audio_file_path in audio_files:

            # Carregar o arquivo de áudio
            audio_data, sample_rate = librosa.load(audio_file_path,sr=44100)
            audio_data = librosa.util.fix_length(audio_data, size=int(4 * 44100))
            # Extrair características (exemplo: MFCCs)

            mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40)
            mfccs_mean = np.mean(mfccs.T, axis=0)  # Média dos MFCCs ao longo do tempo


            # Extração de Chroma
            chroma = librosa.feature.chroma_stft(y=audio_data, sr=sample_rate)
            chroma_mean = np.mean(chroma, axis=1)

            # Extração de Spectral Contrast
            spectral_contrast = librosa.feature.spectral_contrast(y=audio_data, sr=sample_rate)
            spectral_contrast_mean = np.mean(spectral_contrast, axis=1)

            # Extração de Zero Crossing Rate
            zero_crossing_rate = librosa.feature.zero_crossing_rate(audio_data)
            zero_crossing_rate_mean = np.mean(zero_crossing_rate)

            # Combinando todas as características
            combined_features = np.hstack((mfccs_mean, chroma_mean, spectral_contrast_mean, zero_crossing_rate_mean))

            # Adicionar características à lista
            features.append(combined_features)

            audio_file = audio_file_path.split("/")[-1]
            label=dfclass.loc[dfclass['slice_file_name'] == audio_file, 'class'].iloc[0]
            # Adicionar o rótulo à lista (modificar conforme necessário)
           
            labels.append(label)

        df = pd.DataFrame(features)
        df.to_csv(f"csv/features{fold}.csv")
        dl= pd.DataFrame(labels)
        dl.to_csv(f"csv/labels{fold}.csv")
        print(f"{fold} finished")           
 


load_data(FOLDS_PATH)
# Out:
# /home/guilherme/.local/lib/python3.8/site-packages/librosa/core/pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# fold1 finished
# fold10 finished
# fold2 finished
# fold3 finished
# fold4 finished
# fold5 finished
# fold6 finished
# fold7 finished
# fold8 finished
# fold9 finished

# %% [markdown]
# ## Vamos observar cada fold em particular

# %%
def analyze_fold(fold_number):
    # Carregar características e rótulos do fold específico
    features_path = f"csv/featuresfold{fold_number}.csv"
    labels_path = f"csv/labelsfold{fold_number}.csv"
    df_labels = pd.read_csv(labels_path)

    # Adicionar os rótulos ao DataFrame das características
    

    # Observar rótulos únicos
    unique_labels = df_labels['0'].unique()
    print(f"Etiquetas únicas no conjunto de dados do fold {fold_number}: {unique_labels}\n")

for i in range(1,11):
    analyze_fold(i)
# Out:
# Etiquetas únicas no conjunto de dados do fold 1: ['dog_bark' 'gun_shot' 'jackhammer' 'engine_idling' 'children_playing'
#  'siren' 'street_music' 'air_conditioner' 'drilling' 'car_horn']
#
# Etiquetas únicas no conjunto de dados do fold 2: ['dog_bark' 'engine_idling' 'siren' 'drilling' 'children_playing'
#  'air_conditioner' 'car_horn' 'street_music' 'gun_shot' 'jackhammer']
#
# Etiquetas únicas no conjunto de dados do fold 3: ['dog_bark' 'drilling' 'engine_idling' 'gun_shot' 'car_horn' 'siren'
#  'children_playing' 'air_conditioner' 'street_music' 'jackhammer']
#
# Etiquetas únicas no conjunto de dados do fold 4: ['dog_bark' 'street_music' 'jackhammer' 'siren' 'car_horn' 'engine_idling'
#  'drilling' 'gun_shot' 'children_playing' 'air_conditioner']
#
# Etiquetas únicas no conjunto de dados do fold 5: ['dog_bark' 'children_playing' 'air_conditioner' 'jackhammer'
#  'street_music' 'engine_idling' 'siren' 'drilling' 'car_horn' 'gun_shot']
#
# Etiquetas únicas no conjunto de dados do fold 6: ['dog_bark' 'children_playing' 'engine_idling' 'drilling' 'street_music'
#  'gun_shot' 'air_conditioner' 'siren' 'car_horn' 'jackhammer']
#
# Etiquetas únicas no conjunto de dados do fold 7: ['street_music' 'siren' 'drilling' 'dog_bark' 'engine_idling' 'gun_shot'
#  'car_horn' 'air_conditioner' 'jackhammer' 'children_playing']
#
# Etiquetas únicas no conjunto de dados do fold 8: ['dog_bark' 'engine_idling' 'car_horn' 'street_music' 'siren' 'jackhammer'
#  'gun_shot' 'children_playing' 'drilling' 'air_conditioner']
#
# Etiquetas únicas no conjunto de dados do fold 9: ['air_conditioner' 'engine_idling' 'jackhammer' 'dog_bark' 'gun_shot'
#  'drilling' 'children_playing' 'car_horn' 'street_music' 'siren']
#
# Etiquetas únicas no conjunto de dados do fold 10: ['car_horn' 'dog_bark' 'children_playing' 'engine_idling' 'street_music'
#  'drilling' 'air_conditioner' 'gun_shot' 'siren' 'jackhammer']

# %%
def plot_label_distribution_all_folds(n_folds):
    # Número de linhas e colunas para os subplots
    nrows = 2
    ncols = 5

    # Configurar o layout para os subplots
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, 8))  # Ajuste o tamanho conforme necessário

    for fold_number in range(1, n_folds + 1):
        # Carregar os rótulos do fold específico
        labels_path = f"csv/labelsfold{fold_number}.csv"
        df_labels = pd.read_csv(labels_path)

        # Determinar a posição do subplot
        row = (fold_number - 1) // ncols
        col = (fold_number - 1) % ncols

        # Plotar o gráfico no subplot correspondente
        sns.countplot(x=df_labels['0'], ax=axes[row, col])
        axes[row, col].set_title(f'Fold {fold_number}')
        axes[row, col].set_xlabel('Classe')
        axes[row, col].set_ylabel('Frequência')
        axes[row, col].tick_params(axis='x', rotation=45)

    # Ajustar o layout e exibir a figura
    plt.tight_layout()
    plt.show()

# Exemplo de uso para todos os 10 folds
plot_label_distribution_all_folds(10)

# %%
# Preparando o layout para os subplots
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(15, 20))  #tamanho dos subplots
axes = axes.flatten()  # array unidimensional

processed_labels = set()
label_count = 0

folds = [fold for fold in os.listdir(FOLDS_PATH) if "fold" in fold]
for fold in folds:
    audio_files = librosa.util.find_files(FOLDS_PATH+"/"+fold)
    features = []
    labels = []
    for audio_file_path in audio_files:

        # Carregar o arquivo de áudio
        audio_data, sample_rate = librosa.load(audio_file_path)
        audio_file = audio_file_path.split("/")[-1]
        label=dfclass.loc[dfclass['slice_file_name'] == audio_file, 'class'].iloc[0]

        if label not in processed_labels:
            processed_labels.add(label)

            # Meter grafico no subplot correspondente
            librosa.display.specshow(librosa.amplitude_to_db(librosa.stft(audio_data), ref=np.max), 
                                     sr=sample_rate, 
                                     x_axis='time', 
                                     y_axis='log', 
                                     ax=axes[label_count])
            axes[label_count].set_title(f'Label: {label}') 
            label_count += 1
            if label_count >= 10:  # Se já tiver os 10 graficos
                break

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_11372/664023078.py:24: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   librosa.display.specshow(librosa.amplitude_to_db(librosa.stft(audio_data), ref=np.max),

# %% [markdown]
# ## K-Fold Cross Validation

# %% [markdown]
# ### Para a CNN

# %%
def kfold(n_folds,label_encoder):
    accuracies = []
    conf_matrices = []
    all_histories = []
    scaler = StandardScaler()
    for test_fold in range(1, n_folds + 1):
        X_train, y_train = [], []
        for fold in range(1, n_folds + 1):
            features_file = f'csv/featuresfold{fold}.csv'
            labels_file = f'csv/labelsfold{fold}.csv'
            features, encoded_labels = load_fold_data(features_file, labels_file, label_encoder)

            if fold == test_fold:
                X_test, y_test = features, encoded_labels
            else:
                X_train.append(features)
                y_train.append(encoded_labels)

        # Concatenar e preparar os dados de treino
        X_train = np.concatenate(X_train, axis=0)
        y_train = np.concatenate(y_train, axis=0)
        
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        # Conversão para formato categórico
        y_train_categorical = to_categorical(y_train)
        y_test_categorical = to_categorical(y_test)
        
        model = Sequential()
        model.add(Conv1D(32, 3, input_shape=(X_train.shape[1], 1)))
        model.add(LeakyReLU(alpha=0.1))
        model.add(MaxPooling1D(2))
        model.add(Dropout(0.3))
        model.add(Conv1D(64, 3))
        model.add(LeakyReLU(alpha=0.1))
        model.add(MaxPooling1D(2))
        model.add(Dropout(0.4))
        model.add(Conv1D(128, 3))
        model.add(LeakyReLU(alpha=0.1))
        model.add(Flatten())
        model.add(Dropout(0.5))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(10, activation='softmax'))

        optimizer = Adam(learning_rate=0.001)
        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        
        hist = model.fit(X_train, y_train_categorical, epochs=50, batch_size=32, validation_data=(X_test, y_test_categorical), callbacks=[early_stopping])

        # Construir, compilar e treinar o modelo
        all_histories.append(hist.history)
        # Avaliação do modelo
        test_loss, test_accuracy = model.evaluate(X_test, y_test_categorical)
        y_pred = model.predict(X_test)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_true_classes = np.argmax(y_test_categorical, axis=1)
        
        conf_mat = confusion_matrix(y_true_classes, y_pred_classes)
        conf_matrices.append(conf_mat)
        
        accuracies.append(test_accuracy)
        
    mean_conf_matrix = np.mean(conf_matrices, axis=0)
    print("Matriz de Confusão Média:\n", mean_conf_matrix)
    print(f"Acurácia média: {mean_accuracy:.2f}, Desvio padrão: {std_accuracy:.2f}")
    return all_histories, mean_conf_matrix, mean_accuracy, std_accuracy

# %% [markdown]
# ### Para o MLP

# %%
def kfoldmlp(n_folds, label_encoder, num_classes):
    accuracies = []
    conf_matrices = []
    all_histories = []
    scaler = StandardScaler()

    for test_fold in range(1, n_folds + 1):
        X_train, y_train = [], []
        for fold in range(1, n_folds + 1):
            features_file = f'csv/featuresfold{fold}.csv'
            labels_file = f'csv/labelsfold{fold}.csv'
            features, encoded_labels = load_fold_data(features_file, labels_file, label_encoder)

            if fold == test_fold:
                X_test, y_test = features, encoded_labels
            else:
                X_train.append(features)
                y_train.append(encoded_labels)

        # Concatenar e preparar os dados de treino
        X_train = np.concatenate(X_train, axis=0)
        y_train = np.concatenate(y_train, axis=0)
        
        X_train = X_train.reshape((X_train.shape[0], -1))
        X_test = X_test.reshape((X_test.shape[0], -1))

        # Normalizar os dados
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        # Conversão para formato categórico
        y_train_categorical = to_categorical(y_train, num_classes=num_classes)
        y_test_categorical = to_categorical(y_test, num_classes=num_classes)

        modelMLP = Sequential()
        modelMLP.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
        modelMLP.add(Dropout(0.3))
        modelMLP.add(Dense(128, activation='relu'))
        modelMLP.add(Dense(10, activation='softmax'))

        optimizer = Adam(learning_rate=0.001)
        modelMLP.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        # Construir, compilar e treinar o modelo
        hist = modelMLP.fit(X_train, y_train_categorical, epochs=25, batch_size=64, validation_data=(X_test, y_test_categorical), callbacks=[early_stopping])
        all_histories.append(hist.history)

        # Avaliação do modelo
        test_loss, test_accuracy = modelMLP.evaluate(X_test, y_test_categorical)
        y_pred = modelMLP.predict(X_test)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_true_classes = np.argmax(y_test_categorical, axis=1)
        
        conf_mat = confusion_matrix(y_true_classes, y_pred_classes)
        conf_matrices.append(conf_mat)
        accuracies.append(test_accuracy)

    mean_conf_matrix = np.mean(conf_matrices, axis=0)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)

    print("Matriz de Confusão Média:\n", mean_conf_matrix)
    print(f"Acurácia média: {mean_accuracy:.2f}, Desvio padrão: {std_accuracy:.2f}")

    return all_histories, mean_conf_matrix, mean_accuracy, std_accuracy

# %% [markdown]
# ## Primeiro Modelo Convulsional Neural Network

# %% [markdown]
# ### Definir a arquitetura:
#
# ##### Camadas Conv1D: Duas camadas convolucionais com 64 e 128 filtros, respectivamente, e kernels de tamanho 3. Essas camadas são responsáveis por extrair características relevantes dos dados de áudio.
#
# ##### Camadas MaxPooling1D: Seguindo cada camada convolucional, estas camadas reduzem a dimensionalidade dos dados, o que ajuda a diminuir a complexidade computacional e a combater o overfitting.
#
# ##### Camada Flatten: Transforma os dados de uma forma multidimensional para um vetor unidimensional, preparando-os para a próxima etapa de processamento.
#
# ##### Camada Densa e Dropout: Uma camada densa com 128 neurônios é seguida por uma camada de dropout que ajuda a prevenir o overfitting ao descartar aleatoriamente parte dos sinais.
#
# ##### Camada de Saída: Uma camada densa com uma função de ativação 'softmax', utilizada para a classificação multiclasse. O número de neurônios nesta camada corresponde ao número de classes a serem previstas.
#
# ### Compilação do Modelo
#
# ##### O modelo é compilado com o otimizador 'adam' e a função de perda 'categorical_crossentropy', com 'accuracy' como métrica de desempenho. Este setup é padrão para problemas de classificação multiclasse.

# %% [markdown]
# ### K-Fold Cross Validation com os folds predefenidos

# %%
n_folds = 10
accuracies = []
conf_matrices = []
all_histories = []

label_encoder = create_label_mapping(FOLDS_PATH, n_folds)

all_histories, mean_conf_matrix, mean_accuracy, std_accuracy=kfold(10,label_encoder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/campiao/LIACD/AC2/p-deep-learning-classifiers-for-urban-sound-data/Modified_Project_Notebook .ipynb Cell 21 line 8
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/campiao/LIACD/AC2/p-deep-learning-classifiers-for-urban-sound-data/Modified_Project_Notebook%20.ipynb#Y151sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> all_histories = []
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/campiao/LIACD/AC2/p-deep-learning-classifiers-for-urban-sound-data/Modified_Project_Notebook%20.ipynb#Y151sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> label_encoder = create_label_mapping(FOLDS_PATH, n_folds)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/campiao/LIACD/AC2/p-deep-learning-classifiers-for-urban-sound-data/Modified_Project_Notebook%20.ipynb#Y151sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> all_histories, mean_conf_matrix, mean_accuracy, std_accuracy=kfold(10,label_encoder)
#
# NameError: name 'kfold' is not defined

# %%
import matplotlib.pyplot as plt

def plot_all_histories(all_histories):
    # Define o número de linhas e colunas para a grade de subplots
    n_rows = 10  # Uma linha para cada fold
    n_cols = 2   # Duas colunas: uma para acurácia e outra para perda

    # Cria uma figura grande para acomodar todos os subplots
    plt.figure(figsize=(15, 50))  # Ajuste o tamanho conforme necessário

    for i, history in enumerate(all_histories):
        epochs = range(1, len(history['accuracy']) + 1)

        # Subplot para acurácia
        plt.subplot(n_rows, n_cols, 2*i + 1)
        plt.plot(epochs, history['accuracy'], label='Training Accuracy')
        plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'Fold {i+1} - Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()

        # Subplot para perda
        plt.subplot(n_rows, n_cols, 2*i + 2)
        plt.plot(epochs, history['loss'], label='Training Loss')
        plt.plot(epochs, history['val_loss'], label='Validation Loss')
        plt.title(f'Fold {i+1} - Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Chamar a função para plotar todos os históricos
plot_all_histories(all_histories)

# %% [markdown]
# ## Segundo Modelo: Multi-Layer Perceptron

# %%
import keras
keras.utils.plot_model(modelMLP, 'MLP.png', show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/campiao/LIACD/AC2/p-deep-learning-classifiers-for-urban-sound-data/Modified_Project_Notebook .ipynb Cell 24 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/campiao/LIACD/AC2/p-deep-learning-classifiers-for-urban-sound-data/Modified_Project_Notebook%20.ipynb#Y154sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import keras
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/campiao/LIACD/AC2/p-deep-learning-classifiers-for-urban-sound-data/Modified_Project_Notebook%20.ipynb#Y154sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> keras.utils.plot_model(modelMLP, 'MLP.png', show_shapes=True)
#
# NameError: name 'modelMLP' is not defined

# %%
n_folds = 10
accuracies = []
conf_matrices = []
all_histories = []

label_encoder = create_label_mapping(FOLDS_PATH, n_folds)
all_histories, mean_conf_matrix, mean_accuracy, std_accuracy=kfoldmlp(n_folds, label_encoder, 10)
# Out:
# Epoch 1/25
# 123/123 [==============================] - 1s 5ms/step - loss: 1.3407 - categorical_accuracy: 0.5464 - val_loss: 1.6813 - val_categorical_accuracy: 0.4845
# Epoch 2/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.7539 - categorical_accuracy: 0.7598 - val_loss: 1.8521 - val_categorical_accuracy: 0.5143
# Epoch 3/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.5723 - categorical_accuracy: 0.8138 - val_loss: 2.1553 - val_categorical_accuracy: 0.5200
# Epoch 4/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4683 - categorical_accuracy: 0.8525 - val_loss: 2.2293 - val_categorical_accuracy: 0.5395
# Epoch 5/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4073 - categorical_accuracy: 0.8701 - val_loss: 2.2184 - val_categorical_accuracy: 0.5384
# Epoch 6/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3601 - categorical_accuracy: 0.8847 - val_loss: 2.3433 - val_categorical_accuracy: 0.5361
# Epoch 7/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3092 - categorical_accuracy: 0.9018 - val_loss: 2.4600 - val_categorical_accuracy: 0.5395
# Epoch 8/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2861 - categorical_accuracy: 0.9018 - val_loss: 2.5706 - val_categorical_accuracy: 0.5407
# Epoch 9/25
# 123/123 [==============================] - 0s 2ms/step - loss: 0.2493 - categorical_accuracy: 0.9210 - val_loss: 2.6045 - val_categorical_accuracy: 0.5269
# Epoch 10/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2361 - categorical_accuracy: 0.9243 - val_loss: 2.8159 - val_categorical_accuracy: 0.5155
# Epoch 11/25
# 123/123 [==============================] - 0s 2ms/step - loss: 0.2132 - categorical_accuracy: 0.9286 - val_loss: 2.9505 - val_categorical_accuracy: 0.5361
# 28/28 [==============================] - 0s 2ms/step - loss: 1.6813 - categorical_accuracy: 0.4845
# 28/28 [==============================] - 0s 1ms/step
# Epoch 1/25
# 123/123 [==============================] - 1s 4ms/step - loss: 1.3500 - categorical_accuracy: 0.5414 - val_loss: 1.2780 - val_categorical_accuracy: 0.4989
# Epoch 2/25
# 123/123 [==============================] - 0s 2ms/step - loss: 0.7782 - categorical_accuracy: 0.7434 - val_loss: 1.3144 - val_categorical_accuracy: 0.5169
# Epoch 3/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.6099 - categorical_accuracy: 0.7979 - val_loss: 1.5309 - val_categorical_accuracy: 0.5495
# Epoch 4/25
# 123/123 [==============================] - 0s 2ms/step - loss: 0.5065 - categorical_accuracy: 0.8378 - val_loss: 1.5911 - val_categorical_accuracy: 0.5304
# Epoch 5/25
# 123/123 [==============================] - 0s 2ms/step - loss: 0.4191 - categorical_accuracy: 0.8689 - val_loss: 1.6299 - val_categorical_accuracy: 0.5563
# Epoch 6/25
# 123/123 [==============================] - 0s 2ms/step - loss: 0.3656 - categorical_accuracy: 0.8814 - val_loss: 1.7367 - val_categorical_accuracy: 0.5822
# Epoch 7/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3404 - categorical_accuracy: 0.8921 - val_loss: 1.8128 - val_categorical_accuracy: 0.5597
# Epoch 8/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2966 - categorical_accuracy: 0.9044 - val_loss: 1.8906 - val_categorical_accuracy: 0.5777
# Epoch 9/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2655 - categorical_accuracy: 0.9123 - val_loss: 2.0749 - val_categorical_accuracy: 0.5845
# Epoch 10/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2504 - categorical_accuracy: 0.9169 - val_loss: 2.1370 - val_categorical_accuracy: 0.5653
# Epoch 11/25
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2305 - categorical_accuracy: 0.9226 - val_loss: 2.1806 - val_categorical_accuracy: 0.5822
# 28/28 [==============================] - 0s 2ms/step - loss: 1.2780 - categorical_accuracy: 0.4989
# 28/28 [==============================] - 0s 1ms/step
# Epoch 1/25
# 122/122 [==============================] - 1s 4ms/step - loss: 1.3375 - categorical_accuracy: 0.5500 - val_loss: 1.4039 - val_categorical_accuracy: 0.5384
# Epoch 2/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.7533 - categorical_accuracy: 0.7509 - val_loss: 1.4971 - val_categorical_accuracy: 0.5503
# Epoch 3/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.5675 - categorical_accuracy: 0.8139 - val_loss: 1.7308 - val_categorical_accuracy: 0.5373
# Epoch 4/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.4676 - categorical_accuracy: 0.8491 - val_loss: 1.8499 - val_categorical_accuracy: 0.5222
# Epoch 5/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.4067 - categorical_accuracy: 0.8683 - val_loss: 1.9765 - val_categorical_accuracy: 0.5438
# Epoch 6/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.3555 - categorical_accuracy: 0.8868 - val_loss: 2.0613 - val_categorical_accuracy: 0.5286
# Epoch 7/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.3091 - categorical_accuracy: 0.8975 - val_loss: 2.3207 - val_categorical_accuracy: 0.5265
# Epoch 8/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.3016 - categorical_accuracy: 0.8992 - val_loss: 2.2719 - val_categorical_accuracy: 0.5449
# Epoch 9/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2681 - categorical_accuracy: 0.9120 - val_loss: 2.3943 - val_categorical_accuracy: 0.5211
# Epoch 10/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2509 - categorical_accuracy: 0.9149 - val_loss: 2.4457 - val_categorical_accuracy: 0.5524
# Epoch 11/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2295 - categorical_accuracy: 0.9247 - val_loss: 2.5158 - val_categorical_accuracy: 0.5286
# 29/29 [==============================] - 0s 2ms/step - loss: 1.4039 - categorical_accuracy: 0.5384
# 29/29 [==============================] - 0s 1ms/step
# Epoch 1/25
# 121/121 [==============================] - 1s 4ms/step - loss: 1.2982 - categorical_accuracy: 0.5619 - val_loss: 1.3412 - val_categorical_accuracy: 0.5768
# Epoch 2/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.7495 - categorical_accuracy: 0.7573 - val_loss: 1.2908 - val_categorical_accuracy: 0.6091
# Epoch 3/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.5843 - categorical_accuracy: 0.8137 - val_loss: 1.3882 - val_categorical_accuracy: 0.5889
# Epoch 4/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.4801 - categorical_accuracy: 0.8419 - val_loss: 1.4057 - val_categorical_accuracy: 0.6162
# Epoch 5/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.4108 - categorical_accuracy: 0.8706 - val_loss: 1.4719 - val_categorical_accuracy: 0.6101
# Epoch 6/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.3687 - categorical_accuracy: 0.8781 - val_loss: 1.4984 - val_categorical_accuracy: 0.6071
# Epoch 7/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.3190 - categorical_accuracy: 0.8990 - val_loss: 1.5933 - val_categorical_accuracy: 0.6020
# Epoch 8/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.2945 - categorical_accuracy: 0.9055 - val_loss: 1.5775 - val_categorical_accuracy: 0.6020
# Epoch 9/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.2703 - categorical_accuracy: 0.9115 - val_loss: 1.6825 - val_categorical_accuracy: 0.5808
# Epoch 10/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.2483 - categorical_accuracy: 0.9212 - val_loss: 1.7221 - val_categorical_accuracy: 0.5929
# Epoch 11/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.2290 - categorical_accuracy: 0.9253 - val_loss: 1.7199 - val_categorical_accuracy: 0.6111
# Epoch 12/25
# 121/121 [==============================] - 0s 3ms/step - loss: 0.2096 - categorical_accuracy: 0.9296 - val_loss: 1.8293 - val_categorical_accuracy: 0.5949
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2908 - categorical_accuracy: 0.6091
# 31/31 [==============================] - 0s 2ms/step
# Epoch 1/25
# 122/122 [==============================] - 1s 5ms/step - loss: 1.3343 - categorical_accuracy: 0.5519 - val_loss: 1.1998 - val_categorical_accuracy: 0.6165
# Epoch 2/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.7718 - categorical_accuracy: 0.7530 - val_loss: 1.1247 - val_categorical_accuracy: 0.6271
# Epoch 3/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.5965 - categorical_accuracy: 0.8028 - val_loss: 1.1054 - val_categorical_accuracy: 0.6207
# Epoch 4/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.4916 - categorical_accuracy: 0.8400 - val_loss: 1.1579 - val_categorical_accuracy: 0.6325
# Epoch 5/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.4214 - categorical_accuracy: 0.8622 - val_loss: 1.2076 - val_categorical_accuracy: 0.6186
# Epoch 6/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.3711 - categorical_accuracy: 0.8797 - val_loss: 1.1369 - val_categorical_accuracy: 0.6453
# Epoch 7/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.3276 - categorical_accuracy: 0.8949 - val_loss: 1.1672 - val_categorical_accuracy: 0.6571
# Epoch 8/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.3026 - categorical_accuracy: 0.9029 - val_loss: 1.3705 - val_categorical_accuracy: 0.6517
# Epoch 9/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2720 - categorical_accuracy: 0.9105 - val_loss: 1.3504 - val_categorical_accuracy: 0.6442
# Epoch 10/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2480 - categorical_accuracy: 0.9197 - val_loss: 1.3979 - val_categorical_accuracy: 0.6485
# Epoch 11/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2264 - categorical_accuracy: 0.9244 - val_loss: 1.4919 - val_categorical_accuracy: 0.6378
# Epoch 12/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2145 - categorical_accuracy: 0.9301 - val_loss: 1.4352 - val_categorical_accuracy: 0.6496
# Epoch 13/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2006 - categorical_accuracy: 0.9332 - val_loss: 1.4019 - val_categorical_accuracy: 0.6474
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1054 - categorical_accuracy: 0.6207
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/25
# 124/124 [==============================] - 1s 4ms/step - loss: 1.3393 - categorical_accuracy: 0.5537 - val_loss: 1.5391 - val_categorical_accuracy: 0.4496
# Epoch 2/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.7727 - categorical_accuracy: 0.7518 - val_loss: 1.6061 - val_categorical_accuracy: 0.4885
# Epoch 3/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.5957 - categorical_accuracy: 0.8025 - val_loss: 1.6477 - val_categorical_accuracy: 0.5553
# Epoch 4/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4934 - categorical_accuracy: 0.8351 - val_loss: 1.7256 - val_categorical_accuracy: 0.5407
# Epoch 5/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4193 - categorical_accuracy: 0.8628 - val_loss: 1.8494 - val_categorical_accuracy: 0.5529
# Epoch 6/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3706 - categorical_accuracy: 0.8799 - val_loss: 1.8456 - val_categorical_accuracy: 0.5796
# Epoch 7/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3307 - categorical_accuracy: 0.8877 - val_loss: 1.8057 - val_categorical_accuracy: 0.5832
# Epoch 8/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3086 - categorical_accuracy: 0.8964 - val_loss: 1.9391 - val_categorical_accuracy: 0.5820
# Epoch 9/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2718 - categorical_accuracy: 0.9147 - val_loss: 1.9046 - val_categorical_accuracy: 0.5930
# Epoch 10/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2553 - categorical_accuracy: 0.9150 - val_loss: 1.9201 - val_categorical_accuracy: 0.5796
# Epoch 11/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2309 - categorical_accuracy: 0.9264 - val_loss: 2.0785 - val_categorical_accuracy: 0.5772
# 26/26 [==============================] - 0s 2ms/step - loss: 1.5391 - categorical_accuracy: 0.4496
# 26/26 [==============================] - 0s 2ms/step
# Epoch 1/25
# 124/124 [==============================] - 1s 4ms/step - loss: 1.3320 - categorical_accuracy: 0.5492 - val_loss: 1.3312 - val_categorical_accuracy: 0.5442
# Epoch 2/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.7732 - categorical_accuracy: 0.7459 - val_loss: 1.2908 - val_categorical_accuracy: 0.5990
# Epoch 3/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.5993 - categorical_accuracy: 0.8048 - val_loss: 1.2807 - val_categorical_accuracy: 0.6062
# Epoch 4/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.5096 - categorical_accuracy: 0.8327 - val_loss: 1.2364 - val_categorical_accuracy: 0.6229
# Epoch 5/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4179 - categorical_accuracy: 0.8590 - val_loss: 1.2537 - val_categorical_accuracy: 0.6360
# Epoch 6/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3783 - categorical_accuracy: 0.8743 - val_loss: 1.1764 - val_categorical_accuracy: 0.6539
# Epoch 7/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3382 - categorical_accuracy: 0.8923 - val_loss: 1.2491 - val_categorical_accuracy: 0.6480
# Epoch 8/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2928 - categorical_accuracy: 0.9065 - val_loss: 1.3279 - val_categorical_accuracy: 0.6635
# Epoch 9/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2643 - categorical_accuracy: 0.9140 - val_loss: 1.2724 - val_categorical_accuracy: 0.6718
# Epoch 10/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2469 - categorical_accuracy: 0.9160 - val_loss: 1.2992 - val_categorical_accuracy: 0.6599
# Epoch 11/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2339 - categorical_accuracy: 0.9236 - val_loss: 1.3824 - val_categorical_accuracy: 0.6647
# Epoch 12/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2172 - categorical_accuracy: 0.9307 - val_loss: 1.3499 - val_categorical_accuracy: 0.6802
# Epoch 13/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2007 - categorical_accuracy: 0.9349 - val_loss: 1.4919 - val_categorical_accuracy: 0.6539
# Epoch 14/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.1877 - categorical_accuracy: 0.9384 - val_loss: 1.3368 - val_categorical_accuracy: 0.6718
# Epoch 15/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.1762 - categorical_accuracy: 0.9412 - val_loss: 1.3851 - val_categorical_accuracy: 0.6504
# Epoch 16/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.1673 - categorical_accuracy: 0.9445 - val_loss: 1.4361 - val_categorical_accuracy: 0.6563
# 27/27 [==============================] - 0s 2ms/step - loss: 1.1764 - categorical_accuracy: 0.6539
# 27/27 [==============================] - 0s 1ms/step
# Epoch 1/25
# 124/124 [==============================] - 1s 4ms/step - loss: 1.2991 - categorical_accuracy: 0.5614 - val_loss: 1.1882 - val_categorical_accuracy: 0.6216
# Epoch 2/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.7459 - categorical_accuracy: 0.7523 - val_loss: 1.1630 - val_categorical_accuracy: 0.6588
# Epoch 3/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.5770 - categorical_accuracy: 0.8107 - val_loss: 1.2114 - val_categorical_accuracy: 0.6650
# Epoch 4/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4812 - categorical_accuracy: 0.8465 - val_loss: 1.2990 - val_categorical_accuracy: 0.6439
# Epoch 5/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4121 - categorical_accuracy: 0.8666 - val_loss: 1.2989 - val_categorical_accuracy: 0.6737
# Epoch 6/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3629 - categorical_accuracy: 0.8796 - val_loss: 1.5330 - val_categorical_accuracy: 0.6290
# Epoch 7/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3218 - categorical_accuracy: 0.8902 - val_loss: 1.5834 - val_categorical_accuracy: 0.6414
# Epoch 8/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2949 - categorical_accuracy: 0.9039 - val_loss: 1.4434 - val_categorical_accuracy: 0.6824
# Epoch 9/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2651 - categorical_accuracy: 0.9126 - val_loss: 1.5292 - val_categorical_accuracy: 0.6365
# Epoch 10/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2461 - categorical_accuracy: 0.9206 - val_loss: 1.6348 - val_categorical_accuracy: 0.6501
# Epoch 11/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2263 - categorical_accuracy: 0.9242 - val_loss: 1.6006 - val_categorical_accuracy: 0.6687
# Epoch 12/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2107 - categorical_accuracy: 0.9330 - val_loss: 1.6379 - val_categorical_accuracy: 0.6687
# 26/26 [==============================] - 0s 1ms/step - loss: 1.1630 - categorical_accuracy: 0.6588
# 26/26 [==============================] - 0s 1ms/step
# Epoch 1/25
# 124/124 [==============================] - 1s 3ms/step - loss: 1.3209 - categorical_accuracy: 0.5571 - val_loss: 1.2982 - val_categorical_accuracy: 0.5772
# Epoch 2/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.7663 - categorical_accuracy: 0.7484 - val_loss: 1.3266 - val_categorical_accuracy: 0.6103
# Epoch 3/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.5901 - categorical_accuracy: 0.8100 - val_loss: 1.3690 - val_categorical_accuracy: 0.6275
# Epoch 4/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4908 - categorical_accuracy: 0.8411 - val_loss: 1.3616 - val_categorical_accuracy: 0.6360
# Epoch 5/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4176 - categorical_accuracy: 0.8627 - val_loss: 1.4216 - val_categorical_accuracy: 0.6679
# Epoch 6/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3675 - categorical_accuracy: 0.8799 - val_loss: 1.5498 - val_categorical_accuracy: 0.6471
# Epoch 7/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3309 - categorical_accuracy: 0.8922 - val_loss: 1.5960 - val_categorical_accuracy: 0.6544
# Epoch 8/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2968 - categorical_accuracy: 0.9023 - val_loss: 1.5476 - val_categorical_accuracy: 0.6801
# Epoch 9/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2751 - categorical_accuracy: 0.9087 - val_loss: 1.5654 - val_categorical_accuracy: 0.6520
# Epoch 10/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2495 - categorical_accuracy: 0.9180 - val_loss: 1.6573 - val_categorical_accuracy: 0.6667
# Epoch 11/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2270 - categorical_accuracy: 0.9267 - val_loss: 1.7037 - val_categorical_accuracy: 0.6532
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2982 - categorical_accuracy: 0.5772
# 26/26 [==============================] - 0s 1ms/step
# Epoch 1/25
# 124/124 [==============================] - 1s 4ms/step - loss: 1.3241 - categorical_accuracy: 0.5585 - val_loss: 1.1942 - val_categorical_accuracy: 0.5938
# Epoch 2/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.7724 - categorical_accuracy: 0.7467 - val_loss: 1.1931 - val_categorical_accuracy: 0.6033
# Epoch 3/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.5908 - categorical_accuracy: 0.8094 - val_loss: 1.1965 - val_categorical_accuracy: 0.6511
# Epoch 4/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4954 - categorical_accuracy: 0.8400 - val_loss: 1.2138 - val_categorical_accuracy: 0.6189
# Epoch 5/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.4304 - categorical_accuracy: 0.8605 - val_loss: 1.2989 - val_categorical_accuracy: 0.6464
# Epoch 6/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3733 - categorical_accuracy: 0.8802 - val_loss: 1.1999 - val_categorical_accuracy: 0.6571
# Epoch 7/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.3311 - categorical_accuracy: 0.8902 - val_loss: 1.1670 - val_categorical_accuracy: 0.6798
# Epoch 8/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2981 - categorical_accuracy: 0.9031 - val_loss: 1.2809 - val_categorical_accuracy: 0.6607
# Epoch 9/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2780 - categorical_accuracy: 0.9066 - val_loss: 1.3055 - val_categorical_accuracy: 0.6452
# Epoch 10/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2629 - categorical_accuracy: 0.9140 - val_loss: 1.3359 - val_categorical_accuracy: 0.6631
# Epoch 11/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2399 - categorical_accuracy: 0.9193 - val_loss: 1.2913 - val_categorical_accuracy: 0.6798
# Epoch 12/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2216 - categorical_accuracy: 0.9279 - val_loss: 1.4210 - val_categorical_accuracy: 0.6523
# Epoch 13/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.2038 - categorical_accuracy: 0.9327 - val_loss: 1.4493 - val_categorical_accuracy: 0.6535
# Epoch 14/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.1860 - categorical_accuracy: 0.9395 - val_loss: 1.3824 - val_categorical_accuracy: 0.6906
# Epoch 15/25
# 124/124 [==============================] - 0s 2ms/step - loss: 0.1863 - categorical_accuracy: 0.9384 - val_loss: 1.5226 - val_categorical_accuracy: 0.6595
# Epoch 16/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.1742 - categorical_accuracy: 0.9408 - val_loss: 1.5305 - val_categorical_accuracy: 0.6547
# Epoch 17/25
# 124/124 [==============================] - 0s 3ms/step - loss: 0.1619 - categorical_accuracy: 0.9482 - val_loss: 1.6297 - val_categorical_accuracy: 0.6452
# 27/27 [==============================] - 0s 2ms/step - loss: 1.1670 - categorical_accuracy: 0.6798
# 27/27 [==============================] - 0s 1ms/step
# Matriz de Confusão Média:
#  [[31.1  2.  12.2  2.8  9.6 15.3  0.1  9.8  5.2 11.9]
#  [ 0.8 28.5  1.7  5.2  1.8  0.4  1.9  0.3  0.   2.3]
#  [ 9.3  0.5 59.6  6.9  2.5  4.1  0.1  2.   4.7 10.3]
#  [ 5.4  2.8  5.2 70.7  3.5  1.8  2.4  0.3  2.9  5. ]
#  [ 3.1  2.7  5.1  8.  54.4  2.2  2.8 15.3  1.9  4.5]
#  [16.2  0.2  7.   4.8  1.9 47.4  0.9 10.2  5.5  5.9]
#  [ 0.3  0.5  0.   6.4  0.4  0.  28.3  1.5  0.   0. ]
#  [13.5  0.6  0.2  0.5 19.5 10.   3.6 50.1  0.   2. ]
#  [ 3.7  0.5  7.2  6.3  1.1  3.5  0.1  0.5 67.5  2.5]
#  [ 7.6  0.8 11.2  2.2  2.9  3.8  0.   2.5  2.9 66.1]]
# Acurácia média: 0.58, Desvio padrão: 0.08

# %%
import matplotlib.pyplot as plt

def plot_all_histories(all_histories):
    # Define o número de linhas e colunas para a grade de subplots
    n_rows = 10  # Uma linha para cada fold
    n_cols = 2   # Duas colunas: uma para acurácia e outra para perda

    # Cria uma figura grande para acomodar todos os subplots
    plt.figure(figsize=(15, 50))  # Ajuste o tamanho conforme necessário

    for i, history in enumerate(all_histories):
        epochs = range(1, len(history['categorical_accuracy']) + 1)

        # Subplot para acurácia
        plt.subplot(n_rows, n_cols, 2*i + 1)
        plt.plot(epochs, history['categorical_accuracy'], label='Training Accuracy')
        plt.plot(epochs, history['val_categorical_accuracy'], label='Validation Accuracy')
        plt.title(f'Fold {i+1} - Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()

        # Subplot para perda
        plt.subplot(n_rows, n_cols, 2*i + 2)
        plt.plot(epochs, history['loss'], label='Training Loss')
        plt.plot(epochs, history['val_loss'], label='Validation Loss')
        plt.title(f'Fold {i+1} - Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Chamar a função para plotar todos os históricos
plot_all_histories(all_histories)

# %% [markdown]
# # Daqui para baixo é brincando e vendo

# %%
from tensorflow.keras import layers, models
chromagram_shape = (12, 321, 1)

chromagram_input = keras.Input(shape=chromagram_shape, name='chromagram_input')

chromalayer = layers.Conv2D(64, (4,4), activation='relu')(chromagram_input)
# chromalayer = layers.Conv2D(64, (3,3), activation='relu')(chromalayer)
chromalayer = layers.MaxPooling2D((2,2))(chromalayer)
chromalayer = layers.Dropout(0.2)(chromalayer)
# chromalayer = layers.Conv2D(64, (3,3), activation='relu')(chromalayer)
chromalayer = layers.Flatten()(chromalayer)

mel_shape = (128, 321, 1)

mel_spectogram_input = keras.Input(shape=mel_shape, name='mel_spectogram_input')

mellayer = layers.Conv2D(64, (3,3), activation='relu')(mel_spectogram_input)
mellayer = layers.MaxPooling2D((2,2))(mellayer)
mellayer = layers.Dropout(0.3)(mellayer)
mellayer = layers.Conv2D(32, (3,3), activation='relu')(mellayer)
mellayer = layers.MaxPooling2D((2,2))(mellayer)
mellayer = layers.Dropout(0.3)(mellayer)
mellayer = layers.Flatten()(mellayer)

tempogram_shape = (508, 322, 1)

fourier_tempogram = keras.Input(shape=tempogram_shape, name='fourier_tempogram')

fourierlayer = layers.Conv2D(128, (3,3), activation='relu')(fourier_tempogram)
fourierlayer = layers.MaxPooling2D((3,3))(fourierlayer)
fourierlayer = layers.Conv2D(64, (3,3), activation='relu')(fourierlayer)
fourierlayer = layers.MaxPooling2D((3,3))(fourierlayer)	
fourierlayer = layers.Dropout(0.3)(fourierlayer)
fourierlayer = layers.Conv2D(32, (3,3), activation='relu')(fourierlayer)
# fourierlayer = layers.Dropout(0.4)(fourierlayer)
# fourierlayer = layers.Conv2D(64, (3,3), activation='relu')(fourierlayer)
fourierlayer = layers.Flatten()(fourierlayer)

features_1d_shape = (321, 4)

features_1d = keras.Input(shape=features_1d_shape, name='features_1d')

featureslayer = layers.Conv1D(32, 3, activation='relu')(features_1d)
featureslayer = layers.MaxPooling1D(2)(featureslayer)
featureslayer = layers.Conv1D(64, 3, activation='relu')(featureslayer)
featureslayer = layers.MaxPooling1D(2)(featureslayer)
featureslayer = layers.Dropout(0.2)(featureslayer)
featureslayer = layers.Conv1D(64, 3, activation='relu')(featureslayer)
featureslayer = layers.Flatten()(featureslayer)

combined = layers.concatenate([chromalayer, fourierlayer, mellayer, featureslayer])
combined = layers.Dense(128, activation='relu')(combined)
combined = layers.Dropout(0.2)(combined)
combined = layers.Dense(64, activation='relu')(combined)
combined = layers.Dropout(0.2)(combined)
combined = layers.Dense(32, activation='relu')(combined)
combined = layers.Dropout(0.2)(combined)
combined = layers.Dense(10, activation='softmax')(combined)

model = keras.Model(inputs=[chromagram_input, mel_spectogram_input, fourier_tempogram, features_1d], outputs=combined)

model.compile(optimizer='', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# 2023-11-26 23:18:01.462247: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 89456640 exceeds 10% of free system memory.
# 2023-11-26 23:18:01.480420: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 89456640 exceeds 10% of free system memory.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  fourier_tempogram (InputLayer)  [(None, 508, 322, 1  0          []
#                                 )]
#
#  mel_spectogram_input (InputLay  [(None, 128, 321, 1  0          []
#  er)                            )]
#
#  features_1d (InputLayer)       [(None, 321, 4)]     0           []
#
#  conv2d_9 (Conv2D)              (None, 506, 320, 12  1280        ['fourier_tempogram[0][0]']
#                                 8)
#
#  conv2d_7 (Conv2D)              (None, 126, 319, 64  640         ['mel_spectogram_input[0][0]']
#                                 )
#
#  conv1d_25 (Conv1D)             (None, 319, 32)      416         ['features_1d[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 168, 106, 12  0          ['conv2d_9[0][0]']
#                                 8)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 63, 159, 64)  0          ['conv2d_7[0][0]']
#
#  max_pooling1d_24 (MaxPooling1D  (None, 159, 32)     0           ['conv1d_25[0][0]']
#  )
#
#  chromagram_input (InputLayer)  [(None, 12, 321, 1)  0           []
#                                 ]
#
#  conv2d_10 (Conv2D)             (None, 166, 104, 64  73792       ['max_pooling2d_8[0][0]']
#                                 )
#
#  dropout_36 (Dropout)           (None, 63, 159, 64)  0           ['max_pooling2d_6[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 157, 64)      6208        ['max_pooling1d_24[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 9, 318, 64)   1088        ['chromagram_input[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 55, 34, 64)  0           ['conv2d_10[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 61, 157, 32)  18464       ['dropout_36[0][0]']
#
#  max_pooling1d_25 (MaxPooling1D  (None, 78, 64)      0           ['conv1d_26[0][0]']
#  )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 4, 159, 64)  0           ['conv2d_6[0][0]']
#
#  dropout_38 (Dropout)           (None, 55, 34, 64)   0           ['max_pooling2d_9[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 30, 78, 32)  0           ['conv2d_8[0][0]']
#
#  dropout_39 (Dropout)           (None, 78, 64)       0           ['max_pooling1d_25[0][0]']
#
#  dropout_35 (Dropout)           (None, 4, 159, 64)   0           ['max_pooling2d_5[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 53, 32, 32)   18464       ['dropout_38[0][0]']
#
#  dropout_37 (Dropout)           (None, 30, 78, 32)   0           ['max_pooling2d_7[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 76, 64)       12352       ['dropout_39[0][0]']
#
#  flatten_15 (Flatten)           (None, 40704)        0           ['dropout_35[0][0]']
#
#  flatten_17 (Flatten)           (None, 54272)        0           ['conv2d_11[0][0]']
#
#  flatten_16 (Flatten)           (None, 74880)        0           ['dropout_37[0][0]']
#
#  flatten_18 (Flatten)           (None, 4864)         0           ['conv1d_27[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 174720)       0           ['flatten_15[0][0]',
#                                                                   'flatten_17[0][0]',
#                                                                   'flatten_16[0][0]',
#                                                                   'flatten_18[0][0]']
#
#  dense_49 (Dense)               (None, 128)          22364288    ['concatenate_1[0][0]']
#
#  dropout_40 (Dropout)           (None, 128)          0           ['dense_49[0][0]']
#
#  dense_50 (Dense)               (None, 64)           8256        ['dropout_40[0][0]']
#
#  dropout_41 (Dropout)           (None, 64)           0           ['dense_50[0][0]']
#  dense_51 (Dense)               (None, 32)           2080        ['dropout_41[0][0]']
#
#  dropout_42 (Dropout)           (None, 32)           0           ['dense_51[0][0]']
#
#  dense_52 (Dense)               (None, 10)           330         ['dropout_42[0][0]']
#
# ==================================================================================================
# Total params: 22,507,658
# Trainable params: 22,507,658
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, 'multi_input_and_output_model.png', show_shapes=True)

# %%
def kfold(n_folds, label_encoder, num_classes):
    accuracies = []
    conf_matrices = []
    all_histories = []

    for test_fold in range(1, n_folds + 1):
        X_train_list = [[] for _ in range(4)]  # Lista para armazenar os conjuntos de treinamento para cada tipo de entrada
        X_test_list = [[] for _ in range(4)]   # Lista para armazenar os conjuntos de teste para cada tipo de entrada
        y_train, y_test = [], []

        for fold in range(1, n_folds + 1):
            # Suponha que você tenha funções separadas para carregar cada tipo de característica
            chromagram, mel, tempogram, features_1d, labels = load_fold_data(fold, label_encoder)

            if fold == test_fold:
                for X_test, feature_set in zip(X_test_list, [chromagram, mel, tempogram, features_1d]):
                    X_test.append(feature_set)
                y_test = labels
            else:
                for X_train, feature_set in zip(X_train_list, [chromagram, mel, tempogram, features_1d]):
                    X_train.append(feature_set)
                y_train.extend(labels)

        # Concatenar e preparar os dados de treino e teste para cada tipo de entrada
        X_train_list = [np.concatenate(features, axis=0) for features in X_train_list]
        X_test_list = [np.array(features) for features in X_test_list]
        y_train = np.array(y_train)
        y_test = np.array(y_test)

        # Normalizar os dados de entrada (se necessário)
        # ...

        # Conversão para formato categórico
        y_train_categorical = to_categorical(y_train, num_classes)
        y_test_categorical = to_categorical(y_test, num_classes)

        # Treinar o modelo
        hist = model.fit(
            X_train_list, y_train_categorical,
            epochs=10, batch_size=32,
            validation_data=(X_test_list, y_test_categorical),
            verbose=0
        )
        all_histories.append(hist.history)

        # Avaliação do modelo
        test_loss, test_accuracy = model.evaluate(X_test_list, y_test_categorical, verbose=0)
        accuracies.append(test_accuracy)

        # Previsão e matriz de confusão
        y_pred = model.predict(X_test_list, verbose=0)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_true_classes = np.argmax(y_test_categorical, axis=1)
        conf_mat = confusion_matrix(y_true_classes, y_pred_classes)
        conf_matrices.append(conf_mat)

    mean_conf_matrix = np.mean(conf_matrices, axis=0)
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)

    print("Matriz de Confusão Média:\n", mean_conf_matrix)
    print(f"Acurácia média: {mean_accuracy:.2f}, Desvio padrão: {std_accuracy:.2f}")

    return all_histories, mean_conf_matrix, mean_accuracy, std_accuracy

# %%
n_folds = 10
accuracies = []
conf_matrices = []
all_histories = []

label_encoder = create_label_mapping(FOLDS_PATH, n_folds)

all_histories, mean_conf_matrix, mean_accuracy, std_accuracy=kfold(10,label_encoder,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[198], line 8
#       4 all_histories = []
#       6 label_encoder = create_label_mapping(FOLDS_PATH, n_folds)
# ----> 8 all_histories, mean_conf_matrix, mean_accuracy, std_accuracy=kfold(10,label_encoder,10)
#
# Cell In[197], line 13, in kfold(n_folds, label_encoder, num_classes)
#       9 y_train, y_test = [], []
#      11 for fold in range(1, n_folds + 1):
#      12     # Suponha que você tenha funções separadas para carregar cada tipo de característica
# ---> 13     chromagram, mel, tempogram, features_1d, labels = load_fold_data(fold, label_encoder)
#      15     if fold == test_fold:
#      16         for X_test, feature_set in zip(X_test_list, [chromagram, mel, tempogram, features_1d]):
#
# TypeError: load_fold_data() missing 1 required positional argument: 'label_encoder'
